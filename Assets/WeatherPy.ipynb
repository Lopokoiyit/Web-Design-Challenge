# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress

# Import API key
from config import weather_api_key
from config import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Output file
weather_df = pd.read_csv("cities.csv")

# Range of latitudes and longitudes
lat_range = (-50, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
cities = []
lat_long = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-50.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 697

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")
for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | pokhara.
# Processing Record 1  of Set 1 | manzanillo.
# Processing Record 2  of Set 1 | rikitea.
# Processing Record 3  of Set 1 | carnarvon.
# Processing Record 4  of Set 1 | hami.
# Processing Record 5  of Set 1 | troitsko-pechorsk.
# Processing Record 6  of Set 1 | busselton.
# Processing Record 7  of Set 1 | arraial do cabo.
# Processing Record 8  of Set 1 | butaritari.
# Processing Record 9  of Set 1 | dicabisagan.
# Processing Record 10  of Set 1 | kibuye.
# Processing Record 11  of Set 1 | barrow.
# Processing Record 12  of Set 1 | airai.
# Processing Record 13  of Set 1 | louisbourg.
# City not found...skipping louisbourg.
# Processing Record 14  of Set 1 | meadow lake.
# Processing Record 15  of Set 1 | rong kwang.
# Processing Record 16  of Set 1 | arman.
# Processing Record 17  of Set 1 | kitimat.
# Processing Record 18  of Set 1 | tasiilaq.
# Processing Record 19  of Set 1 | meulaboh.
# Processing Record 20  of Set 1 | nanortalik.
# Processing Record 21  of Set 1 | soisy-sous-montmorency.
# Processing Record 22  of Set 1 | tacarigua.
# Processing Record 23  of Set 1 | hithadhoo.
# Processing Record 24  of Set 1 | qaanaaq.
# Processing Record 25  of Set 1 | bethel.
# Processing Record 26  of Set 1 | bonavista.
# Processing Record 27  of Set 1 | itoman.
# Processing Record 28  of Set 1 | aramecina.
# Processing Record 29  of Set 1 | chokurdakh.
# Processing Record 30  of Set 1 | tuktoyaktuk.
# Processing Record 31  of Set 1 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 32  of Set 1 | sindor.
# Processing Record 33  of Set 1 | upernavik.
# Processing Record 34  of Set 1 | ixtapa.
# Processing Record 35  of Set 1 | prabumulih.
# Processing Record 36  of Set 1 | yellowknife.
# Processing Record 37  of Set 1 | yuci.
# Processing Record 38  of Set 1 | east london.
# Processing Record 39  of Set 1 | tommot.
# Processing Record 40  of Set 1 | aksarka.
# Processing Record 41  of Set 1 | tumpat.
# Processing Record 42  of Set 1 | kenai.
# Processing Record 43  of Set 1 | dawlatabad.
# Processing Record 44  of Set 1 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 45  of Set 1 | srednekolymsk.
# Processing Record 46  of Set 1 | sayyan.
# Processing Record 47  of Set 1 | georgetown.
# Processing Record 48  of Set 1 | mount gambier.
# Processing Record 49  of Set 1 | khatanga.
# Processing Record 0  of Set 2 | nikolskoye.
# Processing Record 1  of Set 2 | caravelas.
# Processing Record 2  of Set 2 | bambous virieux.
# Processing Record 3  of Set 2 | hilo.
# Processing Record 4  of Set 2 | bubaque.
# Processing Record 5  of Set 2 | pisco.
# Processing Record 6  of Set 2 | kemijarvi.
# Processing Record 7  of Set 2 | vaini.
# Processing Record 8  of Set 2 | kaeo.
# Processing Record 9  of Set 2 | sao felix do xingu.
# Processing Record 10  of Set 2 | hermanus.
# Processing Record 11  of Set 2 | katangli.
# Processing Record 12  of Set 2 | provideniya.
# Processing Record 13  of Set 2 | codrington.
# Processing Record 14  of Set 2 | namatanai.
# Processing Record 15  of Set 2 | ribeira grande.
# Processing Record 16  of Set 2 | tamale.
# Processing Record 17  of Set 2 | saldanha.
# Processing Record 18  of Set 2 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 19  of Set 2 | jamestown.
# Processing Record 20  of Set 2 | kahului.
# Processing Record 21  of Set 2 | marcona.
# City not found...skipping marcona.
# Processing Record 22  of Set 2 | narsaq.
# Processing Record 23  of Set 2 | faanui.
# Processing Record 24  of Set 2 | idrinskoye.
# Processing Record 25  of Set 2 | hakvik.
# City not found...skipping hakvik.
# Processing Record 26  of Set 2 | mackay.
# Processing Record 27  of Set 2 | jiayuguan.
# Processing Record 28  of Set 2 | bandarbeyla.
# Processing Record 29  of Set 2 | severo-kurilsk.
# Processing Record 30  of Set 2 | lakselv.
# Processing Record 31  of Set 2 | emba.
# Processing Record 32  of Set 2 | ponta do sol.
# Processing Record 33  of Set 2 | lavrentiya.
# Processing Record 34  of Set 2 | blackwater.
# Processing Record 35  of Set 2 | swan hill.
# Processing Record 36  of Set 2 | lebu.
# Processing Record 37  of Set 2 | manado.
# Processing Record 38  of Set 2 | san ramon.
# Processing Record 39  of Set 2 | alcudia.
# Processing Record 40  of Set 2 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 41  of Set 2 | petropavlovsk-kamchatskiy.
# Processing Record 42  of Set 2 | mahebourg.
# Processing Record 43  of Set 2 | port macquarie.
# Processing Record 44  of Set 2 | lompoc.
# Processing Record 45  of Set 2 | mataura.
# Processing Record 46  of Set 2 | peniche.
# Processing Record 47  of Set 2 | aksu.
# Processing Record 48  of Set 2 | samusu.
# City not found...skipping samusu.
# Processing Record 49  of Set 2 | norman wells.
# Processing Record 0  of Set 3 | casper.
# Processing Record 1  of Set 3 | ancud.
# Processing Record 2  of Set 3 | kabardinka.
# Processing Record 3  of Set 3 | vorukh.
# Processing Record 4  of Set 3 | mar del plata.
# Processing Record 5  of Set 3 | kapaa.
# Processing Record 6  of Set 3 | kavieng.
# Processing Record 7  of Set 3 | pevek.
# Processing Record 8  of Set 3 | moron.
# Processing Record 9  of Set 3 | tura.
# Processing Record 10  of Set 3 | cardston.
# Processing Record 11  of Set 3 | opuwo.
# Processing Record 12  of Set 3 | cabo san lucas.
# Processing Record 13  of Set 3 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 14  of Set 3 | glendive.
# Processing Record 15  of Set 3 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 16  of Set 3 | half moon bay.
# Processing Record 17  of Set 3 | denpasar.
# Processing Record 18  of Set 3 | bengkulu.
# Processing Record 19  of Set 3 | pacifica.
# Processing Record 20  of Set 3 | banda aceh.
# Processing Record 21  of Set 3 | castro.
# Processing Record 22  of Set 3 | victoria.
# Processing Record 23  of Set 3 | sakakah.
# Processing Record 24  of Set 3 | flin flon.
# Processing Record 25  of Set 3 | bagdarin.
# Processing Record 26  of Set 3 | vila velha.
# Processing Record 27  of Set 3 | buala.
# Processing Record 28  of Set 3 | hamilton.
# Processing Record 29  of Set 3 | atuona.
# Processing Record 30  of Set 3 | calvia.
# Processing Record 31  of Set 3 | puerto ayora.
# Processing Record 32  of Set 3 | sinnamary.
# Processing Record 33  of Set 3 | pokanayevka.
# City not found...skipping pokanayevka.
# Processing Record 34  of Set 3 | albany.
# Processing Record 35  of Set 3 | kakonko.
# Processing Record 36  of Set 3 | miquelon.
# Processing Record 37  of Set 3 | bartlesville.
# Processing Record 38  of Set 3 | bajo baudo.
# City not found...skipping bajo baudo.
# Processing Record 39  of Set 3 | livingston.
# Processing Record 40  of Set 3 | klaksvik.
# Processing Record 41  of Set 3 | junqueiropolis.
# Processing Record 42  of Set 3 | saskylakh.
# Processing Record 43  of Set 3 | kyaikto.
# Processing Record 44  of Set 3 | alofi.
# Processing Record 45  of Set 3 | mishan.
# Processing Record 46  of Set 3 | itaituba.
# Processing Record 47  of Set 3 | kajaani.
# Processing Record 48  of Set 3 | thompson.
# Processing Record 49  of Set 3 | tuatapere.
# Processing Record 0  of Set 4 | karratha.
# Processing Record 1  of Set 4 | the valley.
# Processing Record 2  of Set 4 | wonthaggi.
# Processing Record 3  of Set 4 | visby.
# Processing Record 4  of Set 4 | fengzhen.
# Processing Record 5  of Set 4 | haines junction.
# Processing Record 6  of Set 4 | las palmas.
# Processing Record 7  of Set 4 | waddan.
# Processing Record 8  of Set 4 | bathsheba.
# Processing Record 9  of Set 4 | lagoa.
# Processing Record 10  of Set 4 | walvis bay.
# Processing Record 11  of Set 4 | urumqi.
# Processing Record 12  of Set 4 | sehithwa.
# Processing Record 13  of Set 4 | ilulissat.
# Processing Record 14  of Set 4 | puerto escondido.
# Processing Record 15  of Set 4 | dikson.
# Processing Record 16  of Set 4 | marienberg.
# Processing Record 17  of Set 4 | manavgat.
# Processing Record 18  of Set 4 | new norfolk.
# Processing Record 19  of Set 4 | hasaki.
# Processing Record 20  of Set 4 | guarapari.
# Processing Record 21  of Set 4 | davila.
# Processing Record 22  of Set 4 | orlik.
# Processing Record 23  of Set 4 | alotau.
# City not found...skipping alotau.
# Processing Record 24  of Set 4 | torbay.
# Processing Record 25  of Set 4 | cape town.
# Processing Record 26  of Set 4 | kieta.
# Processing Record 27  of Set 4 | uthal.
# Processing Record 28  of Set 4 | el fuerte.
# Processing Record 29  of Set 4 | hobart.
# Processing Record 30  of Set 4 | katsuura.
# Processing Record 31  of Set 4 | palu.
# Processing Record 32  of Set 4 | murray bridge.
# Processing Record 33  of Set 4 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 34  of Set 4 | saint-augustin.
# Processing Record 35  of Set 4 | monte alegre.
# Processing Record 36  of Set 4 | ulladulla.
# Processing Record 37  of Set 4 | truth or consequences.
# Processing Record 38  of Set 4 | yulara.
# Processing Record 39  of Set 4 | geraldton.
# Processing Record 40  of Set 4 | sydney.
# Processing Record 41  of Set 4 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 42  of Set 4 | college.
# Processing Record 43  of Set 4 | lata.
# Processing Record 44  of Set 4 | bilma.
# Processing Record 45  of Set 4 | pangnirtung.
# Processing Record 46  of Set 4 | mokolo.
# Processing Record 47  of Set 4 | douentza.
# Processing Record 48  of Set 4 | hovd.
# Processing Record 49  of Set 4 | amderma.
# City not found...skipping amderma.
# Processing Record 0  of Set 5 | samarai.
# Processing Record 1  of Set 5 | nome.
# Processing Record 2  of Set 5 | hermiston.
# Processing Record 3  of Set 5 | stepnyak.
# Processing Record 4  of Set 5 | sept-iles.
# Processing Record 5  of Set 5 | avera.
# Processing Record 6  of Set 5 | dandong.
# Processing Record 7  of Set 5 | karaul.
# City not found...skipping karaul.
# Processing Record 8  of Set 5 | kandrian.
# Processing Record 9  of Set 5 | axim.
# Processing Record 10  of Set 5 | quatre cocos.
# Processing Record 11  of Set 5 | nishihara.
# Processing Record 12  of Set 5 | byron bay.
# Processing Record 13  of Set 5 | merritt island.
# Processing Record 14  of Set 5 | beringovskiy.
# Processing Record 15  of Set 5 | lazaro cardenas.
# Processing Record 16  of Set 5 | santa marta.
# Processing Record 17  of Set 5 | gushikawa.
# Processing Record 18  of Set 5 | punta arenas.
# Processing Record 19  of Set 5 | avarua.
# Processing Record 20  of Set 5 | grindavik.
# Processing Record 21  of Set 5 | guerrero negro.
# Processing Record 22  of Set 5 | paita.
# Processing Record 23  of Set 5 | russell.
# Processing Record 24  of Set 5 | baruun-urt.
# Processing Record 25  of Set 5 | huilong.
# Processing Record 26  of Set 5 | la ronge.
# Processing Record 27  of Set 5 | fortuna.
# Processing Record 28  of Set 5 | luwuk.
# Processing Record 29  of Set 5 | yambio.
# Processing Record 30  of Set 5 | bac lieu.
# Processing Record 31  of Set 5 | banjar.
# Processing Record 32  of Set 5 | chengde.
# Processing Record 33  of Set 5 | lamu.
# Processing Record 34  of Set 5 | chimbote.
# Processing Record 35  of Set 5 | taitung.
# Processing Record 36  of Set 5 | naze.
# Processing Record 37  of Set 5 | ust-nera.
# Processing Record 38  of Set 5 | aklavik.
# Processing Record 39  of Set 5 | vanino.
# Processing Record 40  of Set 5 | pontes e lacerda.
# Processing Record 41  of Set 5 | chuy.
# Processing Record 42  of Set 5 | marsh harbour.
# Processing Record 43  of Set 5 | te anau.
# Processing Record 44  of Set 5 | saint george.
# Processing Record 45  of Set 5 | longyearbyen.
# Processing Record 46  of Set 5 | bundaberg.
# Processing Record 47  of Set 5 | lagos.
# Processing Record 48  of Set 5 | zhicheng.
# Processing Record 49  of Set 5 | panguipulli.
# Processing Record 0  of Set 6 | leningradskiy.
# Processing Record 1  of Set 6 | itaporanga.
# Processing Record 2  of Set 6 | cockburn town.
# Processing Record 3  of Set 6 | kidero.
# Processing Record 4  of Set 6 | clyde river.
# Processing Record 5  of Set 6 | broken hill.
# Processing Record 6  of Set 6 | grand gaube.
# Processing Record 7  of Set 6 | palauig.
# Processing Record 8  of Set 6 | pangai.
# Processing Record 9  of Set 6 | san juan.
# Processing Record 10  of Set 6 | caucaia.
# Processing Record 11  of Set 6 | hualmay.
# Processing Record 12  of Set 6 | santa.
# Processing Record 13  of Set 6 | viligili.
# City not found...skipping viligili.
# Processing Record 14  of Set 6 | saint-philippe.
# Processing Record 15  of Set 6 | saleaula.
# City not found...skipping saleaula.
# Processing Record 16  of Set 6 | tabiauea.
# City not found...skipping tabiauea.
# Processing Record 17  of Set 6 | dukat.
# Processing Record 18  of Set 6 | zhuhai.
# Processing Record 19  of Set 6 | bismarck.
# Processing Record 20  of Set 6 | ranong.
# Processing Record 21  of Set 6 | meyungs.
# City not found...skipping meyungs.
# Processing Record 22  of Set 6 | kudahuvadhoo.
# Processing Record 23  of Set 6 | cidreira.
# Processing Record 24  of Set 6 | moree.
# Processing Record 25  of Set 6 | riwaka.
# Processing Record 26  of Set 6 | magalia.
# Processing Record 27  of Set 6 | mitu.
# Processing Record 28  of Set 6 | talnakh.
# Processing Record 29  of Set 6 | juquitiba.
# Processing Record 30  of Set 6 | rameswaram.
# Processing Record 31  of Set 6 | andenes.
# Processing Record 32  of Set 6 | omsukchan.
# Processing Record 33  of Set 6 | yellapur.
# Processing Record 34  of Set 6 | akyab.
# Processing Record 35  of Set 6 | sitka.
# Processing Record 36  of Set 6 | ginda.
# Processing Record 37  of Set 6 | butterworth.
# Processing Record 38  of Set 6 | vardo.
# Processing Record 39  of Set 6 | kidal.
# Processing Record 40  of Set 6 | hutchinson.
# Processing Record 41  of Set 6 | cherskiy.
# Processing Record 42  of Set 6 | alamosa.
# Processing Record 43  of Set 6 | maniitsoq.
# Processing Record 44  of Set 6 | asyut.
# Processing Record 45  of Set 6 | san pietro in casale.
# Processing Record 46  of Set 6 | sioux lookout.
# Processing Record 47  of Set 6 | iqaluit.
# Processing Record 48  of Set 6 | changji.
# Processing Record 49  of Set 6 | salinopolis.
# Processing Record 0  of Set 7 | acapulco.
# Processing Record 1  of Set 7 | lasa.
# Processing Record 2  of Set 7 | kashary.
# Processing Record 3  of Set 7 | pacific grove.
# Processing Record 4  of Set 7 | northam.
# Processing Record 5  of Set 7 | ifakara.
# Processing Record 6  of Set 7 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 7  of Set 7 | tiarei.
# Processing Record 8  of Set 7 | fort nelson.
# Processing Record 9  of Set 7 | umkomaas.
# Processing Record 10  of Set 7 | tacoronte.
# Processing Record 11  of Set 7 | inarcs.
# Processing Record 12  of Set 7 | prachuap khiri khan.
# Processing Record 13  of Set 7 | sataua.
# City not found...skipping sataua.
# Processing Record 14  of Set 7 | cayenne.
# Processing Record 15  of Set 7 | waipawa.
# Processing Record 16  of Set 7 | qui nhon.
# Processing Record 17  of Set 7 | nyurba.
# Processing Record 18  of Set 7 | gravelbourg.
# Processing Record 19  of Set 7 | zolotinka.
# City not found...skipping zolotinka.
# Processing Record 20  of Set 7 | kropotkin.
# Processing Record 21  of Set 7 | husavik.
# Processing Record 22  of Set 7 | ambilobe.
# Processing Record 23  of Set 7 | sadovoye.
# Processing Record 24  of Set 7 | amurzet.
# Processing Record 25  of Set 7 | virginia beach.
# Processing Record 26  of Set 7 | luanda.
# Processing Record 27  of Set 7 | taltal.
# Processing Record 28  of Set 7 | vallenar.
# Processing Record 29  of Set 7 | freeport.
# Processing Record 30  of Set 7 | eucaliptus.
# Processing Record 31  of Set 7 | tiksi.
# Processing Record 32  of Set 7 | voloshka.
# Processing Record 33  of Set 7 | tarko-sale.
# Processing Record 34  of Set 7 | bredasdorp.
# Processing Record 35  of Set 7 | viedma.
# Processing Record 36  of Set 7 | ye.
# City not found...skipping ye.
# Processing Record 37  of Set 7 | rawannawi.
# City not found...skipping rawannawi.
# Processing Record 38  of Set 7 | paiho.
# City not found...skipping paiho.
# Processing Record 39  of Set 7 | winnemucca.
# Processing Record 40  of Set 7 | kuyanovo.
# Processing Record 41  of Set 7 | warrington.
# Processing Record 42  of Set 7 | kavaratti.
# Processing Record 43  of Set 7 | rakhiv.
# Processing Record 44  of Set 7 | dzhebariki-khaya.
# Processing Record 45  of Set 7 | tazovskiy.
# Processing Record 46  of Set 7 | pyryatyn.
# Processing Record 47  of Set 7 | berezovka.
# Processing Record 48  of Set 7 | finnsnes.
# Processing Record 49  of Set 7 | powell river.
# Processing Record 0  of Set 8 | comodoro rivadavia.
# Processing Record 1  of Set 8 | tevaitoa.
# Processing Record 2  of Set 8 | toktogul.
# Processing Record 3  of Set 8 | vila do maio.
# Processing Record 4  of Set 8 | barsovo.
# Processing Record 5  of Set 8 | tuggurt.
# City not found...skipping tuggurt.
# Processing Record 6  of Set 8 | temaraia.
# City not found...skipping temaraia.
# Processing Record 7  of Set 8 | svetlaya.
# Processing Record 8  of Set 8 | tiptur.
# Processing Record 9  of Set 8 | mandera.
# Processing Record 10  of Set 8 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 11  of Set 8 | mahanoro.
# Processing Record 12  of Set 8 | del rio.
# Processing Record 13  of Set 8 | san vicente.
# Processing Record 14  of Set 8 | la palma.
# Processing Record 15  of Set 8 | manicore.
# Processing Record 16  of Set 8 | kodiak.
# Processing Record 17  of Set 8 | emerald.
# Processing Record 18  of Set 8 | korla.
# Processing Record 19  of Set 8 | aitape.
# Processing Record 20  of Set 8 | saryozek.
# Processing Record 21  of Set 8 | astipalaia.
# City not found...skipping astipalaia.
# Processing Record 22  of Set 8 | coihaique.
# Processing Record 23  of Set 8 | mogadishu.
# Processing Record 24  of Set 8 | kitgum.
# Processing Record 25  of Set 8 | isangel.
# Processing Record 26  of Set 8 | faya.
# Processing Record 27  of Set 8 | flinders.
# Processing Record 28  of Set 8 | ascension.
# Processing Record 29  of Set 8 | koundara.
# Processing Record 30  of Set 8 | ha tinh.
# Processing Record 31  of Set 8 | nexo.
# Processing Record 32  of Set 8 | ormara.
# Processing Record 33  of Set 8 | loncoche.
# Processing Record 34  of Set 8 | mabaruma.
# Processing Record 35  of Set 8 | cerro azul.
# Processing Record 36  of Set 8 | san patricio.
# Processing Record 37  of Set 8 | luderitz.
# Processing Record 38  of Set 8 | taylorville.
# Processing Record 39  of Set 8 | dunedin.
# Processing Record 40  of Set 8 | ereymentau.
# Processing Record 41  of Set 8 | chekhov.
# Processing Record 42  of Set 8 | maumere.
# Processing Record 43  of Set 8 | acajutla.
# Processing Record 44  of Set 8 | bocaiuva.
# Processing Record 45  of Set 8 | malakal.
# Processing Record 46  of Set 8 | bitam.
# Processing Record 47  of Set 8 | alghero.
# Processing Record 48  of Set 8 | alvaraes.
# Processing Record 49  of Set 8 | guantanamo.
# Processing Record 0  of Set 9 | camp verde.
# Processing Record 1  of Set 9 | mount isa.
# Processing Record 2  of Set 9 | kazalinsk.
# City not found...skipping kazalinsk.
# Processing Record 3  of Set 9 | baft.
# Processing Record 4  of Set 9 | saint-joseph.
# Processing Record 5  of Set 9 | artyom.
# Processing Record 6  of Set 9 | belgrade.
# Processing Record 7  of Set 9 | barbar.
# City not found...skipping barbar.
# Processing Record 8  of Set 9 | portland.
# Processing Record 9  of Set 9 | brokopondo.
# Processing Record 10  of Set 9 | mahibadhoo.
# Processing Record 11  of Set 9 | qeshm.
# Processing Record 12  of Set 9 | soyo.
# Processing Record 13  of Set 9 | saint-pierre.
# Processing Record 14  of Set 9 | mayo.
# Processing Record 15  of Set 9 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 16  of Set 9 | vila franca do campo.
# Processing Record 17  of Set 9 | beloha.
# Processing Record 18  of Set 9 | namibe.
# Processing Record 19  of Set 9 | alyangula.
# Processing Record 20  of Set 9 | arlit.
# Processing Record 21  of Set 9 | sao joao da barra.
# Processing Record 22  of Set 9 | aykhal.
# Processing Record 23  of Set 9 | lodwar.
# Processing Record 24  of Set 9 | yerbogachen.
# Processing Record 25  of Set 9 | hervey bay.
# Processing Record 26  of Set 9 | cabedelo.
# Processing Record 27  of Set 9 | dhone.
# Processing Record 28  of Set 9 | asau.
# Processing Record 29  of Set 9 | uige.
# Processing Record 30  of Set 9 | maningrida.
# Processing Record 31  of Set 9 | hobyo.
# Processing Record 32  of Set 9 | taoudenni.
# Processing Record 33  of Set 9 | ahipara.
# Processing Record 34  of Set 9 | kysyl-syr.
# Processing Record 35  of Set 9 | bambari.
# Processing Record 36  of Set 9 | touros.
# Processing Record 37  of Set 9 | san carlos del zulia.
# Processing Record 38  of Set 9 | svetlogorsk.
# Processing Record 39  of Set 9 | zhigansk.
# Processing Record 40  of Set 9 | falam.
# Processing Record 41  of Set 9 | goryachegorsk.
# Processing Record 42  of Set 9 | varkaus.
# Processing Record 43  of Set 9 | thinadhoo.
# Processing Record 44  of Set 9 | constitucion.
# Processing Record 45  of Set 9 | sheltozero.
# Processing Record 46  of Set 9 | hambantota.
# Processing Record 47  of Set 9 | praia da vitoria.
# Processing Record 48  of Set 9 | oistins.
# Processing Record 49  of Set 9 | kaka.
# Processing Record 0  of Set 10 | orvault.
# Processing Record 1  of Set 10 | yumen.
# Processing Record 2  of Set 10 | azua.
# Processing Record 3  of Set 10 | pedana.
# Processing Record 4  of Set 10 | prescott.
# Processing Record 5  of Set 10 | esperance.
# Processing Record 6  of Set 10 | silver city.
# Processing Record 7  of Set 10 | mezen.
# Processing Record 8  of Set 10 | mamakan.
# Processing Record 9  of Set 10 | cham.
# Processing Record 10  of Set 10 | paamiut.
# Processing Record 11  of Set 10 | ulaanbaatar.
# Processing Record 12  of Set 10 | rehoboth.
# Processing Record 13  of Set 10 | muscat.
# Processing Record 14  of Set 10 | port lincoln.
# Processing Record 15  of Set 10 | gergebil.
# Processing Record 16  of Set 10 | birjand.
# Processing Record 17  of Set 10 | beira.
# Processing Record 18  of Set 10 | tecoanapa.
# Processing Record 19  of Set 10 | trelleborg.
# Processing Record 20  of Set 10 | padang.
# Processing Record 21  of Set 10 | nouakchott.
# Processing Record 22  of Set 10 | khasan.
# Processing Record 23  of Set 10 | ta khmau.
# Processing Record 24  of Set 10 | soure.
# Processing Record 25  of Set 10 | teahupoo.
# Processing Record 26  of Set 10 | kalmar.
# Processing Record 27  of Set 10 | valparaiso.
# Processing Record 28  of Set 10 | paradwip.
# City not found...skipping paradwip.
# Processing Record 29  of Set 10 | blairmore.
# Processing Record 30  of Set 10 | leo.
# Processing Record 31  of Set 10 | veraval.
# Processing Record 32  of Set 10 | batemans bay.
# Processing Record 33  of Set 10 | khilok.
# Processing Record 34  of Set 10 | kampong thum.
# Processing Record 35  of Set 10 | shu.
# Processing Record 36  of Set 10 | puerto colombia.
# Processing Record 37  of Set 10 | yala.
# Processing Record 38  of Set 10 | jalu.
# Processing Record 39  of Set 10 | ust-kut.
# Processing Record 40  of Set 10 | williston.
# Processing Record 41  of Set 10 | bayir.
# Processing Record 42  of Set 10 | banyo.
# Processing Record 43  of Set 10 | lokosovo.
# Processing Record 44  of Set 10 | diffa.
# Processing Record 45  of Set 10 | margate.
# Processing Record 46  of Set 10 | tual.
# Processing Record 47  of Set 10 | wau.
# Processing Record 48  of Set 10 | iacobeni.
# Processing Record 49  of Set 10 | belmonte.
# Processing Record 0  of Set 11 | chumikan.
# Processing Record 1  of Set 11 | harper.
# Processing Record 2  of Set 11 | santa rosa.
# Processing Record 3  of Set 11 | teguldet.
# Processing Record 4  of Set 11 | oranjemund.
# Processing Record 5  of Set 11 | dakoro.
# Processing Record 6  of Set 11 | seymchan.
# Processing Record 7  of Set 11 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 8  of Set 11 | chany.
# Processing Record 9  of Set 11 | kundiawa.
# Processing Record 10  of Set 11 | high level.
# Processing Record 11  of Set 11 | mehamn.
# Processing Record 12  of Set 11 | cap malheureux.
# Processing Record 13  of Set 11 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 14  of Set 11 | nagato.
# Processing Record 15  of Set 11 | natal.
# Processing Record 16  of Set 11 | virtsu.
# Processing Record 17  of Set 11 | yar-sale.
# Processing Record 18  of Set 11 | bardiyah.
# Processing Record 19  of Set 11 | tambura.
# Processing Record 20  of Set 11 | auki.
# Processing Record 21  of Set 11 | wasilla.
# Processing Record 22  of Set 11 | champerico.
# Processing Record 23  of Set 11 | tuy hoa.
# Processing Record 24  of Set 11 | lulea.
# Processing Record 25  of Set 11 | empangeni.
# Processing Record 26  of Set 11 | naduvattam.
# Processing Record 27  of Set 11 | uhlove.
# Processing Record 28  of Set 11 | broome.
# Processing Record 29  of Set 11 | komsomolskiy.
# Processing Record 30  of Set 11 | morro bay.
# Processing Record 31  of Set 11 | griffith.
# Processing Record 32  of Set 11 | coquimbo.
# Processing Record 33  of Set 11 | siddharthanagar.
# Processing Record 34  of Set 11 | adrar.
# Processing Record 35  of Set 11 | praya.
# Processing Record 36  of Set 11 | san cristobal.
# Processing Record 37  of Set 11 | ullal.
# Processing Record 38  of Set 11 | bidar.
# Processing Record 39  of Set 11 | kargasok.
# Processing Record 40  of Set 11 | visnes.
# Processing Record 41  of Set 11 | sisimiut.
# Processing Record 42  of Set 11 | nuevo progreso.
# Processing Record 43  of Set 11 | port-gentil.
# Processing Record 44  of Set 11 | ayagoz.
# Processing Record 45  of Set 11 | young.
# Processing Record 46  of Set 11 | salalah.
# Processing Record 47  of Set 11 | yelan.
# Processing Record 48  of Set 11 | yaan.
# Processing Record 49  of Set 11 | ucluelet.
# Processing Record 0  of Set 12 | kununurra.
# Processing Record 1  of Set 12 | hirara.
# Processing Record 2  of Set 12 | mareeba.
# Processing Record 3  of Set 12 | hay river.
# Processing Record 4  of Set 12 | bargal.
# City not found...skipping bargal.
# Processing Record 5  of Set 12 | sao lourenco do sul.
# Processing Record 6  of Set 12 | vanavara.
# Processing Record 7  of Set 12 | xichang.
# Processing Record 8  of Set 12 | egvekinot.
# Processing Record 9  of Set 12 | okhotsk.
# Processing Record 10  of Set 12 | pinega.
# Processing Record 11  of Set 12 | nouadhibou.
# Processing Record 12  of Set 12 | south venice.
# Processing Record 13  of Set 12 | spiridonovka.
# Processing Record 14  of Set 12 | niles.
# Processing Record 15  of Set 12 | coihueco.
# Processing Record 16  of Set 12 | suvorovo.
# Processing Record 17  of Set 12 | shingu.
# Processing Record 18  of Set 12 | kharp.
# Processing Record 19  of Set 12 | londoko.
# Processing Record 20  of Set 12 | marawi.
# Processing Record 21  of Set 12 | san carlos.
# Processing Record 22  of Set 12 | prainha.
# Processing Record 23  of Set 12 | saquisili.
# Processing Record 24  of Set 12 | santa maria.
# Processing Record 25  of Set 12 | erie.
# Processing Record 26  of Set 12 | dzhusaly.
# City not found...skipping dzhusaly.
# Processing Record 27  of Set 12 | shuyskoye.
# Processing Record 28  of Set 12 | solwezi.
# Processing Record 29  of Set 12 | santiago.
# Processing Record 30  of Set 12 | miraflores.
# Processing Record 31  of Set 12 | mitsamiouli.
# Processing Record 32  of Set 12 | lakes entrance.
# Processing Record 33  of Set 12 | san pedro.
# Processing Record 34  of Set 12 | aktau.
# Processing Record 35  of Set 12 | souillac.
# Processing Record 36  of Set 12 | sarangani.
# Processing Record 37  of Set 12 | kuloy.
# Processing Record 38  of Set 12 | vanimo.
# Processing Record 39  of Set 12 | masjed-e soleyman.
# City not found...skipping masjed-e soleyman.
# Processing Record 40  of Set 12 | los llanos de aridane.
# Processing Record 41  of Set 12 | divnomorskoye.
# Processing Record 42  of Set 12 | magadan.
# Processing Record 43  of Set 12 | caconde.
# Processing Record 44  of Set 12 | torrevieja.
# Processing Record 45  of Set 12 | batagay-alyta.
# Processing Record 46  of Set 12 | himora.
# City not found...skipping himora.
# Processing Record 47  of Set 12 | sao filipe.
# Processing Record 48  of Set 12 | zhoucun.
# Processing Record 49  of Set 12 | maldonado.
# Processing Record 0  of Set 13 | little current.
# Processing Record 1  of Set 13 | iralaya.
# Processing Record 2  of Set 13 | kedrovyy.
# Processing Record 3  of Set 13 | havre-saint-pierre.
# Processing Record 4  of Set 13 | itupiranga.
# Processing Record 5  of Set 13 | suntar.
# Processing Record 6  of Set 13 | kinshasa.
# Processing Record 7  of Set 13 | afyonkarahisar.
# Processing Record 8  of Set 13 | svetlyy.
# Processing Record 9  of Set 13 | aswan.
# Processing Record 10  of Set 13 | artyk.
# City not found...skipping artyk.
# Processing Record 11  of Set 13 | ballina.
# Processing Record 12  of Set 13 | tezu.
# Processing Record 13  of Set 13 | maryborough.
# Processing Record 14  of Set 13 | honiara.
# Processing Record 15  of Set 13 | sur.
# Processing Record 16  of Set 13 | arrecife.
# Processing Record 17  of Set 13 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 18  of Set 13 | lucea.
# Processing Record 19  of Set 13 | bongaree.
# Processing Record 20  of Set 13 | mentok.
# City not found...skipping mentok.
# Processing Record 21  of Set 13 | australind.
# Processing Record 22  of Set 13 | riyadh.
# Processing Record 23  of Set 13 | wernigerode.
# Processing Record 24  of Set 13 | borogontsy.
# Processing Record 25  of Set 13 | puerto del rosario.
# Processing Record 26  of Set 13 | buqayq.
# City not found...skipping buqayq.
# Processing Record 27  of Set 13 | vao.
# Processing Record 28  of Set 13 | bayan.
# Processing Record 29  of Set 13 | leh.
# Processing Record 30  of Set 13 | barcelos.
# Processing Record 31  of Set 13 | karaton.
# Processing Record 32  of Set 13 | hailar.
# Processing Record 33  of Set 13 | guanica.
# Processing Record 34  of Set 13 | kutum.
# Processing Record 35  of Set 13 | vestmannaeyjar.
# Processing Record 36  of Set 13 | galle.
# Processing Record 37  of Set 13 | maceio.
# Processing Record 38  of Set 13 | mount pleasant.
# Processing Record 39  of Set 13 | owando.
# Processing Record 40  of Set 13 | shemonaikha.
# Processing Record 41  of Set 13 | houma.
# Processing Record 42  of Set 13 | zhob.
# Processing Record 43  of Set 13 | tabas.
# Processing Record 44  of Set 13 | sheffield lake.
# Processing Record 45  of Set 13 | porto seguro.
# Processing Record 46  of Set 13 | yebaishou.
# Processing Record 47  of Set 13 | sibolga.
# Processing Record 48  of Set 13 | baykit.
# Processing Record 49  of Set 13 | general pico.
# Processing Record 0  of Set 14 | lorengau.
# Processing Record 1  of Set 14 | lolua.
# City not found...skipping lolua.
# Processing Record 2  of Set 14 | kiama.
# Processing Record 3  of Set 14 | abalak.
# Processing Record 4  of Set 14 | reichenau.
# Processing Record 5  of Set 14 | pangody.
# Processing Record 6  of Set 14 | kangaatsiaq.
# Processing Record 7  of Set 14 | santa eulalia del rio.
# City not found...skipping santa eulalia del rio.
# Processing Record 8  of Set 14 | khandyga.
# Processing Record 9  of Set 14 | moba.
# Processing Record 10  of Set 14 | nelson bay.
# Processing Record 11  of Set 14 | yagodnoye.
# Processing Record 12  of Set 14 | sorland.
# Processing Record 13  of Set 14 | new amsterdam.
# Processing Record 14  of Set 14 | shelburne.
# Processing Record 15  of Set 14 | wazzan.
# City not found...skipping wazzan.
# Processing Record 16  of Set 14 | brae.
# Processing Record 17  of Set 14 | liverpool.
# Processing Record 18  of Set 14 | jinka.
# Processing Record 19  of Set 14 | clarence town.
# Processing Record 20  of Set 14 | kloulklubed.
# Processing Record 21  of Set 14 | mecca.
# Processing Record 22  of Set 14 | am timan.
# Processing Record 23  of Set 14 | balaipungut.
# Processing Record 24  of Set 14 | san carlos de bariloche.
# Processing Record 25  of Set 14 | honningsvag.
# Processing Record 26  of Set 14 | brigantine.
# Processing Record 27  of Set 14 | solsona.
# Processing Record 28  of Set 14 | beyneu.
# Processing Record 29  of Set 14 | shache.
# Processing Record 30  of Set 14 | trat.
# Processing Record 31  of Set 14 | manzil tamim.
# City not found...skipping manzil tamim.
# Processing Record 32  of Set 14 | port hardy.
# Processing Record 33  of Set 14 | hashtrud.
# Processing Record 34  of Set 14 | caxias.
# Processing Record 35  of Set 14 | okato.
# Processing Record 36  of Set 14 | rocha.
# Processing Record 37  of Set 14 | igbo ora.
# Processing Record 38  of Set 14 | palanga.
# Processing Record 39  of Set 14 | klyuchi.
# Processing Record 40  of Set 14 | ostrovnoy.
# Processing Record 41  of Set 14 | winchester.
# Processing Record 42  of Set 14 | loiza.
# Processing Record 43  of Set 14 | la presa.
# Processing Record 44  of Set 14 | grand island.
# Processing Record 45  of Set 14 | parabel.
# Processing Record 46  of Set 14 | toora-khem.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()
# Out:
# City                697
# Country             697
# Date                697
# Latitude            697
# Longitude           697
# Cloudiness (%)      697
# Humidity (%)        697
# Max Temp (F)        697
# Wind Speed (mph)    697
# dtype: int64

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")
weather_df.head()
# Out:
#          City Country                 Date Latitude Longitude Cloudiness (%)  \
# 0     pokhara      NP  2022-06-19 22:51:59  28.2333   83.9833             96
# 1  manzanillo      CU  2022-06-19 22:52:00  20.3433  -77.1167            100
# 2     rikitea      PF  2022-06-19 22:52:00 -23.1203 -134.9692            100
# 3   carnarvon      AU  2022-06-19 22:52:01 -24.8667  113.6333              1
# 4        hami      CN  2022-06-19 22:52:02     42.8     93.45            100
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0           84       73.148             2.71
# 1           78        76.19             0.14
# 2           73        72.68             6.05
# 3           70       68.594             5.59
# 4           11       89.294             2.14

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df1= weather_df['Humidity (%)']
weather_df1.head()
# Out:
# 0    84
# 1    78
# 2    73
# 3    70
# 4    11
# Name: Humidity (%), dtype: object

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plot = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({plot})")
print("From our plot we can see that temperature is high at the equator and temperature generally drops as we move away from the equator")
# Out:
# From our plot we can see that temperature is high at the equator and temperature generally drops as we move away from the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plot = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({plot})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plot = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({plot})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plot = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({plot})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, the temperature reduces as you move away from the equator.")
plt.show()
# Out:
# The r-value is: -0.6841031892708707
# The regression displays a negative correlation.
# In the nothern hemisphere, the temperature reduces as you move away from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, the temperature increases as you get closer to the equator.")
plt.show()
# Out:
# The r-value is: 0.8370578235261728
# The regression displays a positive correlation.
# In the southern hemisphere, the temperature increases as you get closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("There is no significant correlation in the data set.") 
plt.show()
# Out:
# The r-value is: 0.03451530581401922
# There is no significant correlation in the data set.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression does not display a correlation between the datasets.")
plt.show()
# Out:
# The r-value is: -0.06398081476829907
# The regression does not display a correlation between the datasets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression does not display a correlation between the data sets.")
plt.show()
# Out:
# The r-value is: -0.0030317325473508583
# The regression does not display a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression displays a positive correlation  with a negative coefficient between the two data sets.The cloudiness reduces in tandem with the latitude.")
plt.show()
# Out:
# The r-value is: -0.08962905648510798
# The regression displays a positive correlation  with a negative coefficient between the two data sets.The cloudiness reduces in tandem with the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression does not display a significant correlation between the data sets.")
plt.show()
# Out:
# The r-value is: 0.03281905119208289
# The regression does not display a significant correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-value is: {rvalue}")
print("The regression displays a positive correlation  with a negative coefficient. As the latitude decreases so does the wind speed.")
plt.show()
# Out:
# The r-value is: -0.14670145046534902
# The regression displays a positive correlation  with a negative coefficient. As the latitude decreases so does the wind speed.
